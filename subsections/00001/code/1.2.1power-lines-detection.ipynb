# %% [markdown]
# # Deep learning for Powerlines Detection

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
'''for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))'''

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# "for dirname, _, filenames in os.walk('/kaggle/input'):\n    for filename in filenames:\n        print(os.path.join(dirname, filename))"

# %%
pip install opencv-python
# Out:
# Collecting opencv-python
#   Using cached opencv_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.2 in /home/jovyan/my-conda-envs/myenv/lib/python3.10/site-packages (from opencv-python) (1.23.5)
# Using cached opencv_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62.5 MB)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.10.0.84
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # ****Function for detecting Horizontal and Vertical edges in a image****

# %% [markdown]
# ### Kernel_1 is for detecting the vertical edges and kernel_2 is for detecting the horizontal edges and this detection makes the image more clear for detecting the power lines

# %%
from scipy.signal import convolve2d
import matplotlib.pyplot as plt

kernel_1 = np.array([[-1, 0, 1],
                   [-1, 0, 1],
                   [-1, 0, 1]])
kernel_2 = np.array([[-1, -1, -1],
                   [0, 0, 0],
                   [1, 1, 1]])
def edge(im):
    out1 = convolve2d(im, kernel_1)
    out2 = convolve2d(im, kernel_2)
    new=np.sqrt(np.square(out1)+np.square(out2))
    return new

def make(im):
    im= cv2.cvtColor(im,cv2.COLOR_RGB2GRAY)
    a=edge(im)
    a=a[:128,:128]
    im1=im.reshape(128,128,1)
    im2=a.reshape(128,128,1)
    return np.concatenate((im1,im2), axis=2)

# %% [markdown]
# # ****Loading the training Dataset****

# %%
import cv2 
import os 
import glob 
img_dir = "/home/jovyan/shared/Learning materials/subsections/1.*/code/data/Powerline/Data/train/Powerline" # Enter Directory of all images  
data_path = os.path.join(img_dir,'*.bmp') 
files = glob.glob(data_path) 
train = [] 
train_labels=[]
images=[]
for f1 in files: 
    img = cv2.imread(f1) 
    images.append(img)
    train.append(make(img))
    train_labels.append(1)

# %%
plt.imshow(images[0])

# %%
img_dir = "/home/jovyan/shared/Learning materials/subsections/1.*/code/data/Powerline/Data/train/No_powerline" # Enter Directory of all images  
data_path = os.path.join(img_dir,'*.bmp') 
files = glob.glob(data_path) 
for f1 in files: 
    img = cv2.imread(f1)
    images.append(img)
    train.append(make(img))
    train_labels.append(0)

# %%
plt.imshow(images[len(images)-1])

# %% [markdown]
# # ****Shuffling the training images and labels****

# %%
import random
temp=list(zip(train,train_labels))
for i in range(20):
    random.shuffle(temp)
train,train_labels=zip(*temp)
train=np.array(train)
train_labels=np.array(train_labels)

# %%
train[0].shape
# Out:
# (128, 128, 2)

# %%
train=np.array(train)
train_labels=np.array(train_labels)

# %%
train.shape
# Out:
# (100, 128, 128, 2)

# %% [markdown]
# # ****Importing the necessary Libraries****

# %%
pip install tensorflow --user
# Out:
# Requirement already satisfied: tensorflow in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (2.14.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from tensorflow) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: ml-dtypes==0.2.0 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy>=1.23.5 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from tensorflow) (1.26.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from tensorflow) (4.21.12)
# Requirement already satisfied: setuptools in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from tensorflow) (60.2.0)
# Requirement already satisfied: six>=1.12.0 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from tensorflow) (4.8.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from tensorflow) (1.54.3)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from tensorflow) (2.14.1)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: keras<2.15,>=2.14.0 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow) (0.41.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (2.23.4)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (3.5.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (2.28.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (0.7.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from seaborn) (1.26.0)
# Requirement already satisfied: pandas>=1.2 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from seaborn) (2.1.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from seaborn) (3.8.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.44.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install np_utils
# Out:
# Requirement already satisfied: np_utils in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (0.6.0)
# Requirement already satisfied: numpy>=1.0 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from np_utils) (1.26.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from keras.utils import to_categorical

# %%
from tensorflow.keras.utils import to_categorical

# %%
pip install --upgrade keras tensorflow
# Out:
# Requirement already satisfied: keras in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (2.14.0)
# Collecting keras
#   Using cached keras-3.4.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: tensorflow in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (2.14.0)
# Collecting tensorflow
#   Downloading tensorflow-2.16.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: absl-py in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from keras) (2.0.0)
# Requirement already satisfied: numpy in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from keras) (1.26.0)
# Requirement already satisfied: rich in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from keras) (13.4.2)
# Collecting namex (from keras)
#   Using cached namex-0.0.8-py3-none-any.whl.metadata (246 bytes)
# Requirement already satisfied: h5py in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from keras) (3.10.0)
# Collecting optree (from keras)
#   Downloading optree-0.12.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.8/47.8 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: ml-dtypes in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from keras) (0.2.0)
# Requirement already satisfied: packaging in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from keras) (23.2)
# Requirement already satisfied: astunparse>=1.6.0 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Using cached libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Collecting ml-dtypes (from keras)
#   Downloading ml_dtypes-0.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from tensorflow) (4.21.12)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from tensorflow) (2.28.2)
# Requirement already satisfied: setuptools in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from tensorflow) (60.2.0)
# Requirement already satisfied: six>=1.12.0 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from tensorflow) (4.8.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from tensorflow) (1.54.3)
# Collecting tensorboard<2.17,>=2.16 (from tensorflow)
#   Using cached tensorboard-2.16.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow)
#   Downloading tensorflow_io_gcs_filesystem-0.37.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow) (0.41.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (2023.7.22)
# Requirement already satisfied: markdown>=2.6.8 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (3.5.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (0.7.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (3.0.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from rich->keras) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow) (2.1.3)
# Using cached keras-3.4.1-py3-none-any.whl (1.1 MB)
# Downloading tensorflow-2.16.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (590.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.6/590.6 MB 836.2 kB/s eta 0:00:0000:0100:01
# Using cached libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl (24.5 MB)
# Downloading ml_dtypes-0.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 32.2 MB/s eta 0:00:00a 0:00:01
# Using cached tensorboard-2.16.2-py3-none-any.whl (5.5 MB)
# Downloading tensorflow_io_gcs_filesystem-0.37.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 34.6 MB/s eta 0:00:0000:0100:01
# Using cached namex-0.0.8-py3-none-any.whl (5.8 kB)
# Downloading optree-0.12.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (347 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 347.7/347.7 kB 8.3 MB/s eta 0:00:00ta 0:00:01
# Installing collected packages: namex, libclang, tensorflow-io-gcs-filesystem, optree, ml-dtypes, tensorboard, keras, tensorflow
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.2.0
#     Uninstalling ml-dtypes-0.2.0:
#       Successfully uninstalled ml-dtypes-0.2.0
#   WARNING: Failed to remove contents in a temporary directory '/home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages/~l_dtypes'.
#   You can safely remove it manually.
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.14.1
#     Uninstalling tensorboard-2.14.1:
#       Successfully uninstalled tensorboard-2.14.1
#   Attempting uninstall: keras
#     Found existing installation: keras 2.14.0
#     Uninstalling keras-2.14.0:
#       Successfully uninstalled keras-2.14.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.14.0
#     Uninstalling tensorflow-2.14.0:
#       Successfully uninstalled tensorflow-2.14.0
#   WARNING: Failed to remove contents in a temporary directory '/home/jovyan/my-conda-envs/py310/lib/python3.10/site-packages/~ensorflow'.
#   You can safely remove it manually.
# Successfully installed keras-3.4.1 libclang-18.1.1 ml-dtypes-0.3.2 namex-0.0.8 optree-0.12.1 tensorboard-2.16.2 tensorflow-2.16.2 tensorflow-io-gcs-filesystem-0.37.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
# %matplotlib inline

np.random.seed(2)

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import itertools

from keras.utils.np_utils import to_categorical # convert to one-hot-encoding
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
from keras.optimizers import RMSprop
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau

sns.set(style='white', context='notebook', palette='deep')
# Out:
# 2024-07-09 11:05:30.010867: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-07-09 11:05:30.069954: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-07-09 11:05:30.070996: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-09 11:05:31.437575: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# # ****Initializing our Model****

# %%
model = Sequential()
model.add(Conv2D(filters = 16, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu', input_shape = (128,128,2)))
model.add(Conv2D(filters = 16, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))



model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                 activation ='relu'))
model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))


model.add(Conv2D(filters = 128, kernel_size = (3,3),padding = 'Same', 
                 activation ='relu'))
model.add(Conv2D(filters = 128, kernel_size = (3,3),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512, activation = "relu"))
model.add(Dropout(0.5))
model.add(Dense(1, activation = "sigmoid"))
# Out:
# 2024-07-09 11:05:43.425137: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-09 11:05:43.425859: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1956] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %% [markdown]
# # ****Model Prototype****

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 16)      816
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 16)      6416
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 16)       0
#  )
#
#  dropout (Dropout)           (None, 64, 64, 16)        0
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 32)        12832
#
#  conv2d_3 (Conv2D)           (None, 64, 64, 32)        25632
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 32, 32)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 32, 32, 32)        0
#
#  conv2d_4 (Conv2D)           (None, 32, 32, 64)        18496
#
#  conv2d_5 (Conv2D)           (None, 32, 32, 64)        36928
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 16, 16, 128)       73856
#
#  conv2d_7 (Conv2D)           (None, 16, 16, 128)       147584
#
#  max_pooling2d_3 (MaxPooling  (None, 8, 8, 128)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 8, 8, 128)         0
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 512)               4194816
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 4,517,889
# Trainable params: 4,517,889
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer =  RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
model.compile(optimizer = optimizer , loss = "binary_crossentropy", metrics=["accuracy"])
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', 
                                            patience=3, 
                                            verbose=1, 
                                            factor=0.5, 
                                            min_lr=0.00001)
# Out:
# /home/jovyan/my-conda-envs/myenv/lib/python3.10/site-packages/keras/optimizers/legacy/rmsprop.py:143: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
epochs = 30 # Turn epochs to 30 to get 0.9967 accuracy
batch_size = 100

# %%
X_train, X_val, Y_train, Y_val = train_test_split(train, train_labels, test_size = 0.1, random_state= 2)
X_train=X_train/255.0
X_val=X_val/255.0

# %%
X_train=train/255.0
Y_train=train_labels

# %% [markdown]
# # ****Training our model****

# %%
history = model.fit( X_train,Y_train, batch_size=batch_size,
                              epochs = 30, 
                              verbose = 1, steps_per_epoch=X_train.shape[0] // batch_size
                               )
# Out:
# Epoch 1/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.6921 - accuracy: 0.5500
# Epoch 2/30
# 1/1 [==============================] - 3s 3s/step - loss: 2.3995 - accuracy: 0.5000
# Epoch 3/30
# 1/1 [==============================] - 3s 3s/step - loss: 0.7233 - accuracy: 0.5000
# Epoch 4/30
# 1/1 [==============================] - 3s 3s/step - loss: 0.6941 - accuracy: 0.5000
# Epoch 5/30
# 1/1 [==============================] - 3s 3s/step - loss: 0.6927 - accuracy: 0.5000
# Epoch 6/30
# 1/1 [==============================] - 3s 3s/step - loss: 0.6934 - accuracy: 0.5100
# Epoch 7/30
# 1/1 [==============================] - 3s 3s/step - loss: 0.6913 - accuracy: 0.5000
# Epoch 8/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.6913 - accuracy: 0.5700
# Epoch 9/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.7204 - accuracy: 0.5000
# Epoch 10/30
# 1/1 [==============================] - 3s 3s/step - loss: 0.6916 - accuracy: 0.5000
# Epoch 11/30
# 1/1 [==============================] - 3s 3s/step - loss: 0.6907 - accuracy: 0.5000
# Epoch 12/30
# 1/1 [==============================] - 3s 3s/step - loss: 0.6898 - accuracy: 0.5000
# Epoch 13/30
# 1/1 [==============================] - 3s 3s/step - loss: 0.6870 - accuracy: 0.5100
# Epoch 14/30
# 1/1 [==============================] - 3s 3s/step - loss: 0.6871 - accuracy: 0.5000
# Epoch 15/30
# 1/1 [==============================] - 3s 3s/step - loss: 0.6950 - accuracy: 0.5000
# Epoch 16/30
# 1/1 [==============================] - 3s 3s/step - loss: 0.6924 - accuracy: 0.5000
# Epoch 17/30
# 1/1 [==============================] - 3s 3s/step - loss: 0.6912 - accuracy: 0.5000
# Epoch 18/30
# 1/1 [==============================] - 3s 3s/step - loss: 0.6882 - accuracy: 0.5400
# Epoch 19/30
# 1/1 [==============================] - 3s 3s/step - loss: 0.6823 - accuracy: 0.6300
# Epoch 20/30
# 1/1 [==============================] - 3s 3s/step - loss: 0.6595 - accuracy: 0.6800
# Epoch 21/30
# 1/1 [==============================] - 3s 3s/step - loss: 1.2408 - accuracy: 0.5000
# Epoch 22/30
# 1/1 [==============================] - 3s 3s/step - loss: 0.7183 - accuracy: 0.5000
# Epoch 23/30
# 1/1 [==============================] - 3s 3s/step - loss: 0.6957 - accuracy: 0.5000
# Epoch 24/30
# 1/1 [==============================] - 3s 3s/step - loss: 0.6939 - accuracy: 0.5000
# Epoch 25/30
# 1/1 [==============================] - 3s 3s/step - loss: 0.6927 - accuracy: 0.5000
# Epoch 26/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.6930 - accuracy: 0.5000
# Epoch 27/30
# 1/1 [==============================] - 3s 3s/step - loss: 0.6931 - accuracy: 0.5000
# Epoch 28/30
# 1/1 [==============================] - 3s 3s/step - loss: 0.6921 - accuracy: 0.5500
# Epoch 29/30
# 1/1 [==============================] - 3s 3s/step - loss: 0.6912 - accuracy: 0.5400
# Epoch 30/30
# 1/1 [==============================] - 3s 3s/step - loss: 0.6886 - accuracy: 0.5000

# %%
del train

# %%
del train_labels

# %% [markdown]
# # ****Loading the test Dataset****

# %%
img_dir = "/home/jovyan/shared/Learning materials/subsections/1.*/code/data/Powerline/Data/test" # Enter Directory of all images  
data_path = os.path.join(img_dir,'*.bmp') 
files = glob.glob(data_path) 
test_images = []
for f1 in files: 
    img = cv2.imread(f1) 
    test_images.append(make(img))

# %%
del X_train

# %%
test_images=np.array(test_images)

# %%
test_images=test_images/255.0

# %%
test_images.shape
# Out:
# (60, 128, 128, 2)

# %% [markdown]
# # ****Predicting the test images****

# %%
test_labels=model.predict(test_images)
# Out:
# 2/2 [==============================] - 0s 127ms/step

# %%
labels=[]
for i in test_labels:
    if(i>0.5):
        labels.append("YES")
    else:
        labels.append("NO")

# %%
test_names=[]
for f1 in files:  
    test_names.append(f1)

# %%
for i in range(0,len(test_images)):
    test_names[i]=test_names[i][39:]
test_names[0]
# Out:
# 'subsections/1.*/code/data/Powerline/Data/test/Check   (1).bmp'

# %%
file=pd.DataFrame(test_names,columns=['image file name'])
file['Powerline']=labels
file
# Out:
#                                       image file name Powerline
# 0   subsections/1.*/code/data/Powerline/Data/test/...       YES
# 1   subsections/1.*/code/data/Powerline/Data/test/...       YES
# 2   subsections/1.*/code/data/Powerline/Data/test/...       YES
# 3   subsections/1.*/code/data/Powerline/Data/test/...       YES
# 4   subsections/1.*/code/data/Powerline/Data/test/...       YES
# 5   subsections/1.*/code/data/Powerline/Data/test/...       YES
# 6   subsections/1.*/code/data/Powerline/Data/test/...       YES
# 7   subsections/1.*/code/data/Powerline/Data/test/...       YES
# 8   subsections/1.*/code/data/Powerline/Data/test/...       YES
# 9   subsections/1.*/code/data/Powerline/Data/test/...        NO
# 10  subsections/1.*/code/data/Powerline/Data/test/...       YES
# 11  subsections/1.*/code/data/Powerline/Data/test/...        NO
# 12  subsections/1.*/code/data/Powerline/Data/test/...       YES
# 13  subsections/1.*/code/data/Powerline/Data/test/...       YES
# 14  subsections/1.*/code/data/Powerline/Data/test/...       YES
# 15  subsections/1.*/code/data/Powerline/Data/test/...        NO
# 16  subsections/1.*/code/data/Powerline/Data/test/...        NO
# 17  subsections/1.*/code/data/Powerline/Data/test/...       YES
# 18  subsections/1.*/code/data/Powerline/Data/test/...        NO
# 19  subsections/1.*/code/data/Powerline/Data/test/...        NO
# 20  subsections/1.*/code/data/Powerline/Data/test/...        NO
# 21  subsections/1.*/code/data/Powerline/Data/test/...       YES
# 22  subsections/1.*/code/data/Powerline/Data/test/...        NO
# 23  subsections/1.*/code/data/Powerline/Data/test/...       YES
# 24  subsections/1.*/code/data/Powerline/Data/test/...       YES
# 25  subsections/1.*/code/data/Powerline/Data/test/...       YES
# 26  subsections/1.*/code/data/Powerline/Data/test/...       YES
# 27  subsections/1.*/code/data/Powerline/Data/test/...        NO
# 28  subsections/1.*/code/data/Powerline/Data/test/...        NO
# 29  subsections/1.*/code/data/Powerline/Data/test/...       YES
# 30  subsections/1.*/code/data/Powerline/Data/test/...        NO
# 31  subsections/1.*/code/data/Powerline/Data/test/...       YES
# 32  subsections/1.*/code/data/Powerline/Data/test/...       YES
# 33  subsections/1.*/code/data/Powerline/Data/test/...        NO
# 34  subsections/1.*/code/data/Powerline/Data/test/...       YES
# 35  subsections/1.*/code/data/Powerline/Data/test/...       YES
# 36  subsections/1.*/code/data/Powerline/Data/test/...       YES
# 37  subsections/1.*/code/data/Powerline/Data/test/...       YES
# 38  subsections/1.*/code/data/Powerline/Data/test/...       YES
# 39  subsections/1.*/code/data/Powerline/Data/test/...       YES
# 40  subsections/1.*/code/data/Powerline/Data/test/...       YES
# 41  subsections/1.*/code/data/Powerline/Data/test/...       YES
# 42  subsections/1.*/code/data/Powerline/Data/test/...       YES
# 43  subsections/1.*/code/data/Powerline/Data/test/...       YES
# 44  subsections/1.*/code/data/Powerline/Data/test/...       YES
# 45  subsections/1.*/code/data/Powerline/Data/test/...       YES
# 46  subsections/1.*/code/data/Powerline/Data/test/...       YES
# 47  subsections/1.*/code/data/Powerline/Data/test/...       YES
# 48  subsections/1.*/code/data/Powerline/Data/test/...       YES
# 49  subsections/1.*/code/data/Powerline/Data/test/...       YES
# 50  subsections/1.*/code/data/Powerline/Data/test/...       YES
# 51  subsections/1.*/code/data/Powerline/Data/test/...       YES
# 52  subsections/1.*/code/data/Powerline/Data/test/...       YES
# 53  subsections/1.*/code/data/Powerline/Data/test/...       YES
# 54  subsections/1.*/code/data/Powerline/Data/test/...       YES
# 55  subsections/1.*/code/data/Powerline/Data/test/...       YES
# 56  subsections/1.*/code/data/Powerline/Data/test/...        NO
# 57  subsections/1.*/code/data/Powerline/Data/test/...       YES
# 58  subsections/1.*/code/data/Powerline/Data/test/...       YES
# 59  subsections/1.*/code/data/Powerline/Data/test/...       YES

# %% [markdown]
# # ****Saving the file for submission****

# %%
file.to_csv('output.csv',index=False)
