# %%
# Clone the YOLOv9 repository
# !git clone https://github.com/carlosfab/yolov9.git

# Change the current working directory to the cloned YOLOv9 repository
# %cd yolov9

# Install the necessary YOLOv9 dependencies from the requirements.txt file
# !pip install -r requirements.txt -q
# Out:
# Cloning into 'yolov9'...
# remote: Enumerating objects: 372, done.
# remote: Counting objects: 100% (247/247), done.
# remote: Compressing objects: 100% (70/70), done.
# remote: Total 372 (delta 183), reused 177 (delta 177), pack-reused 125
# Receiving objects: 100% (372/372), 2.53 MiB | 28.74 MiB/s, done.
# Resolving deltas: 100% (189/189), done.
# Updating files: 100% (111/111), done.
# /home/jovyan/shared/Learning materials/subsections/1.*/code/object/yolov9

# %%
# Import necessary libraries
import sys
import requests
from tqdm.notebook import tqdm
from pathlib import Path
from PIL import Image
from io import BytesIO
import matplotlib.pyplot as plt
from matplotlib.pylab import rcParams

# %%
import os
from pathlib import Path
import requests
from tqdm import tqdm

# Define the folder where weights will be stored
WEIGHTS_FOLDER = Path("./weights")
WEIGHTS_FOLDER.mkdir(parents=True, exist_ok=True)

# List of weight files to download (example URLs)
weight_files = [
    "https://example.com/weight1.pt",
    "https://example.com/weight2.pt"
]

for i, url in enumerate(weight_files, start=1):
    filename = url.split("/")[-1]
    response = requests.get(url, stream=True)
    total_size_in_bytes = int(response.headers.get('content-length', 0))
    block_size = 1024  # 1 Kilobyte
    progress_bar = tqdm(total=total_size_in_bytes, unit='iB', unit_scale=True, desc=f"Downloading file {i}/{len(weight_files)}: {filename}")

    with open(WEIGHTS_FOLDER / filename, 'wb') as file:
        for data in response.iter_content(block_size):
            progress_bar.update(len(data))
            file.write(data)
    progress_bar.close()
# Out:
# Downloading file 1/2: weight1.pt: 100%|██████████| 433/433 [00:00<00:00, 2.74kiB/s]
#
# Downloading file 2/2: weight2.pt: 100%|██████████| 433/433 [00:00<00:00, 4.06kiB/s]

# %%
# URLs of weight files
weight_files = [
    "https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-c.pt",
    "https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-e.pt",
    "https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-c.pt",
    "https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-e.pt"
]

# Iterates over the list of URLs to download the weight files
for i, url in enumerate(weight_files, start=1):
    filename = url.split('/')[-1]
    response = requests.get(url, stream=True)
    total_size_in_bytes = int(response.headers.get('content-length', 0))
    block_size = 1024  # 1 Kilobyte
    progress_bar = tqdm(total=total_size_in_bytes, unit='iB', unit_scale=True, desc=f"Downloading file {i}/{len(weight_files)}: {filename}")
    with open(WEIGHTS_FOLDER / filename, 'wb') as file:
        for data in response.iter_content(block_size):
            progress_bar.update(len(data))
            file.write(data)
    progress_bar.close()
# Out:
# Downloading file 1/4: yolov9-c.pt:   0%|          | 0.00/103M [00:00<?, ?iB/s]
# Downloading file 1/4: yolov9-c.pt:   4%|▎         | 3.86M/103M [00:00<00:02, 38.6MiB/s]
# Downloading file 1/4: yolov9-c.pt:  10%|▉         | 10.1M/103M [00:00<00:01, 52.5MiB/s]
# Downloading file 1/4: yolov9-c.pt:  15%|█▌        | 15.7M/103M [00:00<00:01, 53.9MiB/s]
# Downloading file 1/4: yolov9-c.pt:  21%|██        | 21.2M/103M [00:00<00:01, 54.6MiB/s]
# Downloading file 1/4: yolov9-c.pt:  26%|██▌       | 26.8M/103M [00:00<00:01, 54.9MiB/s]
# Downloading file 1/4: yolov9-c.pt:  31%|███▏      | 32.4M/103M [00:00<00:01, 55.1MiB/s]
# Downloading file 1/4: yolov9-c.pt:  37%|███▋      | 37.9M/103M [00:00<00:01, 55.3MiB/s]
# Downloading file 1/4: yolov9-c.pt:  42%|████▏     | 43.5M/103M [00:00<00:01, 55.4MiB/s]
# Downloading file 1/4: yolov9-c.pt:  48%|████▊     | 49.0M/103M [00:00<00:00, 55.4MiB/s]
# Downloading file 1/4: yolov9-c.pt:  53%|█████▎    | 54.6M/103M [00:01<00:00, 55.6MiB/s]
# Downloading file 1/4: yolov9-c.pt:  58%|█████▊    | 60.2M/103M [00:01<00:00, 55.6MiB/s]
# Downloading file 1/4: yolov9-c.pt:  64%|██████▎   | 65.7M/103M [00:01<00:00, 55.6MiB/s]
# Downloading file 1/4: yolov9-c.pt:  69%|██████▉   | 71.3M/103M [00:01<00:00, 55.6MiB/s]
# Downloading file 1/4: yolov9-c.pt:  75%|███████▍  | 76.9M/103M [00:01<00:00, 55.6MiB/s]
# Downloading file 1/4: yolov9-c.pt:  80%|███████▉  | 82.4M/103M [00:01<00:00, 55.6MiB/s]
# Downloading file 1/4: yolov9-c.pt:  85%|████████▌ | 88.0M/103M [00:01<00:00, 51.1MiB/s]
# Downloading file 1/4: yolov9-c.pt:  91%|█████████ | 94.0M/103M [00:01<00:00, 53.7MiB/s]
# Downloading file 1/4: yolov9-c.pt: 100%|██████████| 103M/103M [00:03<00:00, 28.3MiB/s]
#
# Downloading file 2/4: yolov9-e.pt:   0%|          | 0.00/140M [00:00<?, ?iB/s]
# Downloading file 2/4: yolov9-e.pt:   3%|▎         | 4.46M/140M [00:00<00:03, 44.5MiB/s]
# Downloading file 2/4: yolov9-e.pt:   6%|▋         | 9.00M/140M [00:00<00:02, 45.1MiB/s]
# Downloading file 2/4: yolov9-e.pt:  11%|█         | 15.1M/140M [00:00<00:02, 52.5MiB/s]
# Downloading file 2/4: yolov9-e.pt:  15%|█▍        | 20.8M/140M [00:00<00:02, 54.3MiB/s]
# Downloading file 2/4: yolov9-e.pt:  19%|█▉        | 26.3M/140M [00:00<00:02, 54.5MiB/s]
# Downloading file 2/4: yolov9-e.pt:  23%|██▎       | 31.9M/140M [00:00<00:01, 54.9MiB/s]
# Downloading file 2/4: yolov9-e.pt:  27%|██▋       | 37.5M/140M [00:00<00:01, 55.2MiB/s]
# Downloading file 2/4: yolov9-e.pt:  31%|███       | 43.1M/140M [00:00<00:01, 55.3MiB/s]
# Downloading file 2/4: yolov9-e.pt:  35%|███▍      | 48.6M/140M [00:00<00:01, 55.4MiB/s]
# Downloading file 2/4: yolov9-e.pt:  39%|███▊      | 54.2M/140M [00:01<00:01, 55.5MiB/s]
# Downloading file 2/4: yolov9-e.pt:  43%|████▎     | 59.8M/140M [00:01<00:01, 55.5MiB/s]
# Downloading file 2/4: yolov9-e.pt:  47%|████▋     | 65.3M/140M [00:01<00:01, 55.5MiB/s]
# Downloading file 2/4: yolov9-e.pt:  51%|█████     | 70.9M/140M [00:01<00:01, 55.6MiB/s]
# Downloading file 2/4: yolov9-e.pt:  55%|█████▍    | 76.5M/140M [00:01<00:01, 55.6MiB/s]
# Downloading file 2/4: yolov9-e.pt:  59%|█████▊    | 82.0M/140M [00:01<00:01, 55.6MiB/s]
# Downloading file 2/4: yolov9-e.pt:  62%|██████▏   | 87.6M/140M [00:01<00:00, 55.6MiB/s]
# Downloading file 2/4: yolov9-e.pt:  66%|██████▋   | 93.2M/140M [00:01<00:00, 55.6MiB/s]
# Downloading file 2/4: yolov9-e.pt:  70%|███████   | 98.7M/140M [00:01<00:00, 55.6MiB/s]
# Downloading file 2/4: yolov9-e.pt:  74%|███████▍  | 104M/140M [00:01<00:00, 55.6MiB/s]
# Downloading file 2/4: yolov9-e.pt:  78%|███████▊  | 110M/140M [00:02<00:00, 55.6MiB/s]
# Downloading file 2/4: yolov9-e.pt:  82%|████████▏ | 115M/140M [00:02<00:00, 55.6MiB/s]
# Downloading file 2/4: yolov9-e.pt:  86%|████████▋ | 121M/140M [00:02<00:00, 55.6MiB/s]
# Downloading file 2/4: yolov9-e.pt:  90%|█████████ | 127M/140M [00:02<00:00, 55.6MiB/s]
# Downloading file 2/4: yolov9-e.pt:  94%|█████████▍| 132M/140M [00:02<00:00, 55.6MiB/s]
# Downloading file 2/4: yolov9-e.pt: 100%|██████████| 140M/140M [00:05<00:00, 25.9MiB/s]
#
# Downloading file 3/4: gelan-c.pt:   0%|          | 0.00/51.5M [00:00<?, ?iB/s]
# Downloading file 3/4: gelan-c.pt:   8%|▊         | 4.24M/51.5M [00:00<00:01, 42.4MiB/s]
# Downloading file 3/4: gelan-c.pt:  17%|█▋        | 8.93M/51.5M [00:00<00:00, 45.0MiB/s]
# Downloading file 3/4: gelan-c.pt:  26%|██▌       | 13.4M/51.5M [00:00<00:00, 45.0MiB/s]
# Downloading file 3/4: gelan-c.pt:  37%|███▋      | 18.9M/51.5M [00:00<00:00, 48.9MiB/s]
# Downloading file 3/4: gelan-c.pt:  48%|████▊     | 24.5M/51.5M [00:00<00:00, 51.3MiB/s]
# Downloading file 3/4: gelan-c.pt:  58%|█████▊    | 30.1M/51.5M [00:00<00:00, 52.8MiB/s]
# Downloading file 3/4: gelan-c.pt:  69%|██████▉   | 35.6M/51.5M [00:00<00:00, 53.7MiB/s]
# Downloading file 3/4: gelan-c.pt:  80%|███████▉  | 41.2M/51.5M [00:00<00:00, 54.3MiB/s]
# Downloading file 3/4: gelan-c.pt: 100%|██████████| 51.5M/51.5M [00:02<00:00, 24.3MiB/s]
#
# Downloading file 4/4: gelan-e.pt:   0%|          | 0.00/117M [00:00<?, ?iB/s]
# Downloading file 4/4: gelan-e.pt:   3%|▎         | 3.95M/117M [00:00<00:02, 39.5MiB/s]
# Downloading file 4/4: gelan-e.pt:   8%|▊         | 9.58M/117M [00:00<00:02, 49.0MiB/s]
# Downloading file 4/4: gelan-e.pt:  13%|█▎        | 15.6M/117M [00:00<00:01, 53.9MiB/s]
# Downloading file 4/4: gelan-e.pt:  18%|█▊        | 21.1M/117M [00:00<00:01, 54.4MiB/s]
# Downloading file 4/4: gelan-e.pt:  23%|██▎       | 26.7M/117M [00:00<00:01, 54.9MiB/s]
# Downloading file 4/4: gelan-e.pt:  27%|██▋       | 32.1M/117M [00:00<00:01, 54.6MiB/s]
# Downloading file 4/4: gelan-e.pt:  32%|███▏      | 37.7M/117M [00:00<00:01, 54.9MiB/s]
# Downloading file 4/4: gelan-e.pt:  37%|███▋      | 43.2M/117M [00:00<00:01, 55.1MiB/s]
# Downloading file 4/4: gelan-e.pt:  42%|████▏     | 48.8M/117M [00:00<00:01, 55.2MiB/s]
# Downloading file 4/4: gelan-e.pt:  46%|████▋     | 54.3M/117M [00:01<00:01, 55.1MiB/s]
# Downloading file 4/4: gelan-e.pt:  51%|█████     | 60.0M/117M [00:01<00:01, 55.5MiB/s]
# Downloading file 4/4: gelan-e.pt:  56%|█████▌    | 65.5M/117M [00:01<00:00, 55.5MiB/s]
# Downloading file 4/4: gelan-e.pt:  61%|██████    | 71.1M/117M [00:01<00:00, 55.6MiB/s]
# Downloading file 4/4: gelan-e.pt:  65%|██████▌   | 76.7M/117M [00:01<00:00, 55.6MiB/s]
# Downloading file 4/4: gelan-e.pt:  70%|███████   | 82.2M/117M [00:01<00:00, 55.6MiB/s]
# Downloading file 4/4: gelan-e.pt:  75%|███████▍  | 87.8M/117M [00:01<00:00, 55.6MiB/s]
# Downloading file 4/4: gelan-e.pt:  80%|███████▉  | 93.4M/117M [00:01<00:00, 55.6MiB/s]
# Downloading file 4/4: gelan-e.pt:  84%|████████▍ | 98.9M/117M [00:01<00:00, 55.1MiB/s]
# Downloading file 4/4: gelan-e.pt:  89%|████████▉ | 104M/117M [00:01<00:00, 53.6MiB/s]
# Downloading file 4/4: gelan-e.pt:  94%|█████████▎| 110M/117M [00:02<00:00, 52.7MiB/s]
# Downloading file 4/4: gelan-e.pt: 100%|██████████| 117M/117M [00:05<00:00, 22.4MiB/s]

# %%
# Test image URL
url = 'https://sigmoidal.ai/wp-content/uploads/2022/11/314928609_1293071608150779_8666358890956473002_n.jpg'

# Makes the request to get the image
response = requests.get(url)

# Defines the file path where the image will be saved within DATA_FOLDER
#image_path = DATA_FOLDER / "test_image.jpg"
image_path = "shared/Learning materials/subsections/1.*/code/object/YOLOV9/DATA_FOLDER/"test_image.jpg"

# Saves the image in the specified directory
with open(image_path, 'wb') as f:
    f.write(response.content)
