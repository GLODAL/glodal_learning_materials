# %% [markdown]
# # Sentinel 2 Atmospheric Correction in Google Earth Engine

# %% [markdown]
# ### Import modules
# and initialize Earth Engine

# %%
conda install -c conda-forge earthengine-api
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: unsuccessful initial attempt using frozen solve. Retrying with flexible solve.
# Solving environment: unsuccessful attempt using repodata from current_repodata.json, retrying with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.9.0
#   latest version: 24.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.5.0
#
#
#
# ## Package Plan ##
#
#   environment location: /home/jovyan/my-conda-envs/myenv
#
#   added / updated specs:
#     - earthengine-api
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     aiohttp-3.9.5              |  py310h2372a71_0         682 KB  conda-forge
#     aiosignal-1.3.1            |     pyhd8ed1ab_0          12 KB  conda-forge
#     async-timeout-4.0.3        |     pyhd8ed1ab_0          11 KB  conda-forge
#     cachetools-5.3.3           |     pyhd8ed1ab_0          14 KB  conda-forge
#     cffi-1.16.0                |  py310h2fee648_0         236 KB  conda-forge
#     cryptography-42.0.8        |  py310hb1bd9d3_0         1.9 MB  conda-forge
#     earthengine-api-0.1.410    |     pyhd8ed1ab_0         276 KB  conda-forge
#     frozenlist-1.4.1           |  py310h2372a71_0          58 KB  conda-forge
#     google-api-core-2.19.1     |     pyhd8ed1ab_0          83 KB  conda-forge
#     google-api-python-client-2.136.0|     pyhd8ed1ab_0         5.7 MB  conda-forge
#     google-auth-2.32.0         |     pyhff2d567_0         108 KB  conda-forge
#     google-auth-httplib2-0.2.0 |     pyhd8ed1ab_0          15 KB  conda-forge
#     google-cloud-core-2.4.1    |     pyhd8ed1ab_0          27 KB  conda-forge
#     google-cloud-storage-2.17.0|     pyhff2d567_0          87 KB  conda-forge
#     google-crc32c-1.1.2        |  py310hc5c09a0_5          24 KB  conda-forge
#     google-resumable-media-2.7.0|     pyhd8ed1ab_0          45 KB  conda-forge
#     googleapis-common-protos-1.63.2|     pyhd8ed1ab_0         113 KB  conda-forge
#     grpcio-1.62.2              |  py310h1b8f574_0         980 KB  conda-forge
#     httplib2-0.22.0            |     pyhd8ed1ab_0          93 KB  conda-forge
#     multidict-6.0.5            |  py310h2372a71_0          56 KB  conda-forge
#     proto-plus-1.23.0          |     pyhd8ed1ab_0          41 KB  conda-forge
#     protobuf-4.25.3            |  py310ha8c1f0e_0         325 KB  conda-forge
#     pyasn1-0.6.0               |     pyhd8ed1ab_0          63 KB  conda-forge
#     pyasn1-modules-0.4.0       |     pyhd8ed1ab_0          93 KB  conda-forge
#     pycparser-2.22             |     pyhd8ed1ab_0         103 KB  conda-forge
#     pyopenssl-24.0.0           |     pyhd8ed1ab_0         124 KB  conda-forge
#     pyu2f-0.1.5                |     pyhd8ed1ab_0          31 KB  conda-forge
#     rsa-4.9                    |     pyhd8ed1ab_0          29 KB  conda-forge
#     typing-extensions-4.11.0   |       hd8ed1ab_0          10 KB  conda-forge
#     uritemplate-4.1.1          |     pyhd8ed1ab_0          12 KB  conda-forge
#     yarl-1.9.4                 |  py310h2372a71_0         111 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        11.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   aiohttp            conda-forge/linux-64::aiohttp-3.9.5-py310h2372a71_0
#   aiosignal          conda-forge/noarch::aiosignal-1.3.1-pyhd8ed1ab_0
#   async-timeout      conda-forge/noarch::async-timeout-4.0.3-pyhd8ed1ab_0
#   cachetools         conda-forge/noarch::cachetools-5.3.3-pyhd8ed1ab_0
#   cffi               conda-forge/linux-64::cffi-1.16.0-py310h2fee648_0
#   cryptography       conda-forge/linux-64::cryptography-42.0.8-py310hb1bd9d3_0
#   earthengine-api    conda-forge/noarch::earthengine-api-0.1.410-pyhd8ed1ab_0
#   frozenlist         conda-forge/linux-64::frozenlist-1.4.1-py310h2372a71_0
#   google-api-core    conda-forge/noarch::google-api-core-2.19.1-pyhd8ed1ab_0
#   google-api-python~ conda-forge/noarch::google-api-python-client-2.136.0-pyhd8ed1ab_0
#   google-auth        conda-forge/noarch::google-auth-2.32.0-pyhff2d567_0
#   google-auth-httpl~ conda-forge/noarch::google-auth-httplib2-0.2.0-pyhd8ed1ab_0
#   google-cloud-core  conda-forge/noarch::google-cloud-core-2.4.1-pyhd8ed1ab_0
#   google-cloud-stor~ conda-forge/noarch::google-cloud-storage-2.17.0-pyhff2d567_0
#   google-crc32c      conda-forge/linux-64::google-crc32c-1.1.2-py310hc5c09a0_5
#   google-resumable-~ conda-forge/noarch::google-resumable-media-2.7.0-pyhd8ed1ab_0
#   googleapis-common~ conda-forge/noarch::googleapis-common-protos-1.63.2-pyhd8ed1ab_0
#   grpcio             conda-forge/linux-64::grpcio-1.62.2-py310h1b8f574_0
#   httplib2           conda-forge/noarch::httplib2-0.22.0-pyhd8ed1ab_0
#   multidict          conda-forge/linux-64::multidict-6.0.5-py310h2372a71_0
#   proto-plus         conda-forge/noarch::proto-plus-1.23.0-pyhd8ed1ab_0
#   protobuf           conda-forge/linux-64::protobuf-4.25.3-py310ha8c1f0e_0
#   pyasn1             conda-forge/noarch::pyasn1-0.6.0-pyhd8ed1ab_0
#   pyasn1-modules     conda-forge/noarch::pyasn1-modules-0.4.0-pyhd8ed1ab_0
#   pycparser          conda-forge/noarch::pycparser-2.22-pyhd8ed1ab_0
#   pyopenssl          conda-forge/noarch::pyopenssl-24.0.0-pyhd8ed1ab_0
#   pyu2f              conda-forge/noarch::pyu2f-0.1.5-pyhd8ed1ab_0
#   rsa                conda-forge/noarch::rsa-4.9-pyhd8ed1ab_0
#   typing-extensions  conda-forge/noarch::typing-extensions-4.11.0-hd8ed1ab_0
#   uritemplate        conda-forge/noarch::uritemplate-4.1.1-pyhd8ed1ab_0
#   yarl               conda-forge/linux-64::yarl-1.9.4-py310h2372a71_0
#
#
#
# Downloading and Extracting Packages:
# multidict-6.0.5      | 56 KB     |                                       |   0%
# googleapis-common-pr | 113 KB    |                                       |   0%
#
# cffi-1.16.0          | 236 KB    |                                       |   0%
#
#
# cachetools-5.3.3     | 14 KB     |                                       |   0%
#
#
#
# pyu2f-0.1.5          | 31 KB     |                                       |   0%
#
#
#
#
# pyopenssl-24.0.0     | 124 KB    |                                       |   0%
#
#
#
#
#
# google-api-core-2.19 | 83 KB     |                                       |   0%
#
#
#
#
#
#
# pyasn1-modules-0.4.0 | 93 KB     |                                       |   0%
#
#
#
#
#
#
#
# protobuf-4.25.3      | 325 KB    |                                       |   0%
#
#
#
#
#
#
#
#
# pycparser-2.22       | 103 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# frozenlist-1.4.1     | 58 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# aiosignal-1.3.1      | 12 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# uritemplate-4.1.1    | 12 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# rsa-4.9              | 29 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# httplib2-0.22.0      | 93 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# google-auth-2.32.0   | 108 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# yarl-1.9.4           | 111 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# earthengine-api-0.1. | 276 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyasn1-0.6.0         | 63 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# google-auth-httplib2 | 15 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# google-api-python-cl | 5.7 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# google-cloud-core-2. | 27 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# google-cloud-storage | 87 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# googleapis-common-pr | 113 KB    | #####2                                |  14%
#
#
# cachetools-5.3.3     | 14 KB     | ##################################### | 100%
#
# cffi-1.16.0          | 236 KB    | ##5                                   |   7%
#
#
#
# multidict-6.0.5      | 56 KB     | ##########5                           |  29%
#
#
# cachetools-5.3.3     | 14 KB     | ##################################### | 100%
#
#
#
#
# pyopenssl-24.0.0     | 124 KB    | ####7                                 |  13%
#
#
#
#
#
# google-api-core-2.19 | 83 KB     | #######                               |  19%
#
#
#
#
#
#
# pyasn1-modules-0.4.0 | 93 KB     | ######3                               |  17%
#
#
#
#
#
#
#
# protobuf-4.25.3      | 325 KB    | #8                                    |   5%
#
#
#
#
#
#
#
#
# pycparser-2.22       | 103 KB    | #####7                                |  16%
#
#
#
# pyu2f-0.1.5          | 31 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# frozenlist-1.4.1     | 58 KB     | ##########1                           |  27%
#
#
#
#
#
#
#
#
#
#
#
# uritemplate-4.1.1    | 12 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# aiosignal-1.3.1      | 12 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# httplib2-0.22.0      | 93 KB     | ######3                               |  17%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# google-auth-2.32.0   | 108 KB    | #####4                                |  15%
#
#
#
#
#
#
#
#
#
#
#
#
# multidict-6.0.5      | 56 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# yarl-1.9.4           | 111 KB    | #####3                                |  14%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# earthengine-api-0.1. | 276 KB    | ##1                                   |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyasn1-0.6.0         | 63 KB     | #########4                            |  26%
#
# cffi-1.16.0          | 236 KB    | ##################################### | 100%
#
# cffi-1.16.0          | 236 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# google-auth-httplib2 | 15 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# google-api-python-cl | 5.7 MB    | 1                                     |   0%
#
#
#
#
# pyopenssl-24.0.0     | 124 KB    | ##################################### | 100%
#
#
#
#
# pyopenssl-24.0.0     | 124 KB    | ##################################### | 100%
# googleapis-common-pr | 113 KB    | ##################################### | 100%
# googleapis-common-pr | 113 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# google-cloud-core-2. | 27 KB     | #####################5                |  58%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# google-cloud-storage | 87 KB     | ######7                               |  18%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# google-api-python-cl | 5.7 MB    | #######################4              |  63%
#
#
#
#
#
# google-api-core-2.19 | 83 KB     | ##################################### | 100%
#
#
#
#
#
# google-api-core-2.19 | 83 KB     | ##################################### | 100%
#
#
#
#
#
#
# pyasn1-modules-0.4.0 | 93 KB     | ##################################### | 100%
#
#
#
#
#
#
# pyasn1-modules-0.4.0 | 93 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
# pycparser-2.22       | 103 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# pycparser-2.22       | 103 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# frozenlist-1.4.1     | 58 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# frozenlist-1.4.1     | 58 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# uritemplate-4.1.1    | 12 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# aiosignal-1.3.1      | 12 KB     | ##################################### | 100%
#
#
#
#
#
#
#
# protobuf-4.25.3      | 325 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# protobuf-4.25.3      | 325 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# httplib2-0.22.0      | 93 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# httplib2-0.22.0      | 93 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# rsa-4.9              | 29 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# rsa-4.9              | 29 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# yarl-1.9.4           | 111 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# yarl-1.9.4           | 111 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# google-auth-2.32.0   | 108 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# google-auth-2.32.0   | 108 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# google-auth-httplib2 | 15 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyasn1-0.6.0         | 63 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyasn1-0.6.0         | 63 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# google-cloud-core-2. | 27 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# google-cloud-core-2. | 27 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# google-cloud-storage | 87 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# google-cloud-storage | 87 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# earthengine-api-0.1. | 276 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# earthengine-api-0.1. | 276 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# google-api-python-cl | 5.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda create -n py6s-env -c conda-forge py6s
# Out:
# WARNING: A conda environment already exists at '/home/jovyan/my-conda-envs/py6s-env'
# Remove existing environment (y/[n])? ^C
#
# CondaSystemExit:
# Operation aborted.  Exiting.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyatmos
# Out:
# Collecting pyatmos
#   Downloading pyatmos-1.2.6-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: scipy in /home/jovyan/my-conda-envs/py6s-env/lib/python3.12/site-packages (from pyatmos) (1.14.0)
# Requirement already satisfied: numpy in /home/jovyan/my-conda-envs/py6s-env/lib/python3.12/site-packages (from pyatmos) (2.0.0)
# Collecting numba (from pyatmos)
#   Downloading numba-0.60.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.7 kB)
# Collecting pandas (from pyatmos)
#   Downloading pandas-2.2.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Collecting astropy (from pyatmos)
#   Downloading astropy-6.1.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting wget (from pyatmos)
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pyerfa>=2.0.1.1 (from astropy->pyatmos)
#   Downloading pyerfa-2.0.1.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.7 kB)
# Collecting astropy-iers-data>=0.2024.5.27.0.30.8 (from astropy->pyatmos)
#   Downloading astropy_iers_data-0.2024.7.8.0.31.19-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: PyYAML>=3.13 in /home/jovyan/my-conda-envs/py6s-env/lib/python3.12/site-packages (from astropy->pyatmos) (6.0.1)
# Requirement already satisfied: packaging>=19.0 in /home/jovyan/my-conda-envs/py6s-env/lib/python3.12/site-packages (from astropy->pyatmos) (24.1)
# Collecting llvmlite<0.44,>=0.43.0dev0 (from numba->pyatmos)
#   Downloading llvmlite-0.43.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/jovyan/my-conda-envs/py6s-env/lib/python3.12/site-packages (from pandas->pyatmos) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /home/jovyan/my-conda-envs/py6s-env/lib/python3.12/site-packages (from pandas->pyatmos) (2024.1)
# Collecting tzdata>=2022.7 (from pandas->pyatmos)
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /home/jovyan/my-conda-envs/py6s-env/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->pyatmos) (1.16.0)
# Downloading pyatmos-1.2.6-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.5/47.5 kB 1.8 MB/s eta 0:00:00
# Downloading astropy-6.1.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 32.3 MB/s eta 0:00:0000:010:01
# Downloading numba-0.60.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 30.9 MB/s eta 0:00:0000:0100:01
# Downloading pandas-2.2.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 29.2 MB/s eta 0:00:0000:0100:01
# Downloading astropy_iers_data-0.2024.7.8.0.31.19-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 32.9 MB/s eta 0:00:0000:01
# Downloading llvmlite-0.43.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.9/43.9 MB 16.3 MB/s eta 0:00:0000:0100:01
# Downloading pyerfa-2.0.1.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (738 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 738.7/738.7 kB 22.7 MB/s eta 0:00:00
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9656 sha256=46b12cd3ea25a53872bfee85754f723ba879a1f0768db2046c08a79265ca165b
#   Stored in directory: /home/jovyan/.cache/pip/wheels/01/46/3b/e29ffbe4ebe614ff224bad40fc6a5773a67a163251585a13a9
# Successfully built wget
# Installing collected packages: wget, tzdata, pyerfa, llvmlite, astropy-iers-data, pandas, numba, astropy, pyatmos
# Successfully installed astropy-6.1.1 astropy-iers-data-0.2024.7.8.0.31.19 llvmlite-0.43.0 numba-0.60.0 pandas-2.2.2 pyatmos-1.2.6 pyerfa-2.0.1.4 tzdata-2024.1 wget-3.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import ee
from Py6S import *
import datetime
import math
import os
import sys
sys.path.append(os.path.join(os.path.dirname(os.getcwd()),'bin'))
from atmospheric import Atmospheric

ee.Initialize()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 8
#       6 import sys
#       7 sys.path.append(os.path.join(os.path.dirname(os.getcwd()),'bin'))
# ----> 8 from atmospheric import Atmospheric
#      10 ee.Initialize()
#
# ModuleNotFoundError: No module named 'atmospheric'

# %% [markdown]
# ### time and place
# Define the time and place that you are looking for.

# %%
date = ee.Date('2017-01-01')
geom = ee.Geometry.Point(-157.816222, 21.297481)
geom = ee.Geometry.Point(12.670733, 41.826685)# ESRIN (ESA Earth Observation Centre)

# %% [markdown]
# ### an image
# The following code will grab the first scene that occurs on or after date.

# %%
# The first Sentinel 2 image
S2 = ee.Image(
  ee.ImageCollection('COPERNICUS/S2')
    .filterBounds(geom)
    .filterDate(date,date.advance(3,'month'))
    .sort('system:time_start')
    .first()
  )

# top of atmosphere reflectance
toa = S2.divide(10000)

# %% [markdown]
# ### metadata

# %%
info = S2.getInfo()['properties']
scene_date = datetime.datetime.utcfromtimestamp(info['system:time_start']/1000)# i.e. Python uses seconds, EE uses milliseconds
solar_z = info['MEAN_SOLAR_ZENITH_ANGLE']

# %% [markdown]
# ### atmospheric constituents

# %%
h2o = Atmospheric.water(geom,date).getInfo()
o3 = Atmospheric.ozone(geom,date).getInfo()
aot = Atmospheric.aerosol(geom,date).getInfo()

# %% [markdown]
# ### target altitude (km)

# %%
SRTM = ee.Image('CGIAR/SRTM90_V4')# Shuttle Radar Topography mission covers *most* of the Earth
alt = SRTM.reduceRegion(reducer = ee.Reducer.mean(),geometry = geom.centroid()).get('elevation').getInfo()
km = alt/1000 # i.e. Py6S uses units of kilometers

# %% [markdown]
# ### 6S object
#
# The backbone of Py6S is the 6S (i.e. SixS) class. It allows you to define the various input parameters, to run the radiative transfer code and to access the outputs which are required to convert radiance to surface reflectance.

# %%
# Instantiate
s = SixS()

# Atmospheric constituents
s.atmos_profile = AtmosProfile.UserWaterAndOzone(h2o,o3)
s.aero_profile = AeroProfile.Continental
s.aot550 = aot

# Earth-Sun-satellite geometry
s.geometry = Geometry.User()
s.geometry.view_z = 0               # always NADIR (I think..)
s.geometry.solar_z = solar_z        # solar zenith angle
s.geometry.month = scene_date.month # month and day used for Earth-Sun distance
s.geometry.day = scene_date.day     # month and day used for Earth-Sun distance
s.altitudes.set_sensor_satellite_level()
s.altitudes.set_target_custom_altitude(km)

# %% [markdown]
# ### Spectral Response functions

# %% [markdown]
# Py6S uses the Wavelength class to handle the wavelength(s) associated with a given channel (a.k.a. waveband). This might be a single scalar value (e.g. a central wavelength) or, if known, possibly the spectral response function of the waveband. The Sentinel 2 spectral response functions are provided with Py6S (as well as those of a number of missions). For more details please see the [docs](http://py6s.readthedocs.io/en/latest/params.html#wavelengths) or the (comment-rich) [source code](https://github.com/robintw/Py6S/blob/master/Py6S/Params/wavelength.py)

# %%
def spectralResponseFunction(bandname):
    """
    Extract spectral response function for given band name
    """
    bandSelect = {
        'B1':PredefinedWavelengths.S2A_MSI_01,
        'B2':PredefinedWavelengths.S2A_MSI_02,
        'B3':PredefinedWavelengths.S2A_MSI_03,
        'B4':PredefinedWavelengths.S2A_MSI_04,
        'B5':PredefinedWavelengths.S2A_MSI_05,
        'B6':PredefinedWavelengths.S2A_MSI_06,
        'B7':PredefinedWavelengths.S2A_MSI_07,
        'B8':PredefinedWavelengths.S2A_MSI_08,
        'B8A':PredefinedWavelengths.S2A_MSI_8A,
        'B9':PredefinedWavelengths.S2A_MSI_09,
        'B10':PredefinedWavelengths.S2A_MSI_10,
        'B11':PredefinedWavelengths.S2A_MSI_11,
        'B12':PredefinedWavelengths.S2A_MSI_12,
        }
    return Wavelength(bandSelect[bandname])

# %% [markdown]
# ### TOA Reflectance to Radiance
#
# Sentinel 2 data is provided as top-of-atmosphere reflectance. Lets convert this to at-sensor radiance for the atmospheric correction.*
#
# \*<sub>You *can* atmospherically corrected directly from TOA reflectance. However, I suggest radiance for a couple of reasons.
#   Firstly, it is more intuitive. Instead of *spherical albedo* (which I suspect is more of a mathematical convenience than a physical property) you can use solar irradiance, transmissivity, path radiance, etc. Secondly, Py6S seems to be more geared towards converting from radiance to SR</sup>

# %%
def toa_to_rad(bandname):
    """
    Converts top of atmosphere reflectance to at-sensor radiance
    """
    
    # solar exoatmospheric spectral irradiance
    ESUN = info['SOLAR_IRRADIANCE_'+bandname]
    solar_angle_correction = math.cos(math.radians(solar_z))
    
    # Earth-Sun distance (from day of year)
    doy = scene_date.timetuple().tm_yday
    d = 1 - 0.01672 * math.cos(0.9856 * (doy-4))# http://physics.stackexchange.com/questions/177949/earth-sun-distance-on-a-given-day-of-the-year
   
    # conversion factor
    multiplier = ESUN*solar_angle_correction/(math.pi*d**2)

    # at-sensor radiance
    rad = toa.select(bandname).multiply(multiplier)
    
    return rad

# %% [markdown]
# ### Radiance to Surface Reflectance
#
# Reflected sunlight can be described as follows (wavelength dependence is implied):
#
# $ L = \tau\rho(E_{dir} + E_{dif})/\pi + L_p$
#
# where L is at-sensor radiance, $\tau$ is transmissivity, $\rho$ is surface reflectance, $E_{dir}$ is direct solar irradiance, $E_{dif}$ is diffuse solar irradiance and $L_p$ is path radiance. There are five unknowns in this equation, 4 atmospheric terms ($\tau$, $E_{dir}$, $E_{dif}$ and $L_p$) and surface reflectance. The 6S radiative transfer code is used to solve for the atmospheric terms, allowing us to solve for surface reflectance.
#
# $ \rho = \pi(L - L_p) / \tau(E_{dir} + E_{dif}) $

# %%
def surface_reflectance(bandname):
    """
    Calculate surface reflectance from at-sensor radiance given waveband name
    """
    
    # run 6S for this waveband
    s.wavelength = spectralResponseFunction(bandname)
    s.run()
    
    # extract 6S outputs
    Edir = s.outputs.direct_solar_irradiance             #direct solar irradiance
    Edif = s.outputs.diffuse_solar_irradiance            #diffuse solar irradiance
    Lp   = s.outputs.atmospheric_intrinsic_radiance      #path radiance
    absorb  = s.outputs.trans['global_gas'].upward       #absorption transmissivity
    scatter = s.outputs.trans['total_scattering'].upward #scattering transmissivity
    tau2 = absorb*scatter                                #total transmissivity
    
    # radiance to surface reflectance
    rad = toa_to_rad(bandname)
    ref = rad.subtract(Lp).multiply(math.pi).divide(tau2*(Edir+Edif))
    
    return ref

# %% [markdown]
# ### Atmospheric Correction

# %%
# surface reflectance rgb
b = surface_reflectance('B2')
g = surface_reflectance('B3')
r = surface_reflectance('B4')
ref = r.addBands(g).addBands(b)

# # all wavebands
# output = S2.select('QA60')
# for band in ['B1','B2','B3','B4','B5','B6','B7','B8','B8A','B9','B10','B11','B12']:
#     print(band)
#     output = output.addBands(surface_reflectance(band))

# %% [markdown]
# ### Display results

# %%
from IPython.display import display, Image

region = geom.buffer(5000).bounds().getInfo()['coordinates']
channels = ['B4','B3','B2']

original = Image(url=toa.select(channels).getThumbUrl({
                'region':region,
                'min':0,
                'max':0.25
                }))

corrected = Image(url=ref.select(channels).getThumbUrl({
                'region':region,
                'min':0,
                'max':0.25
                }))

display(original, corrected)
# Out:
# <img src="https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/e7b6e79fe7111740fb17f89fa9f27e9e-ab8335f380538596f3221daaa39b7e0a:getPixels"/>
# <img src="https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/2e7bbc1be7c38eeb9cf82cb1b8ff26d9-85189dcd5930dead83dee3b931e368e1:getPixels"/>

# %% [markdown]
# ### Export to Asset

# %%
# # set some properties for export
# dateString = scene_date.strftime("%Y-%m-%d")
# ref = ref.set({'satellite':'Sentinel 2',
#               'fileID':info['system:index'],
#               'date':dateString,
#               'aerosol_optical_thickness':aot,
#               'water_vapour':h2o,
#               'ozone':o3})

# %%
# define YOUR assetID 
# in my case it was something like this..
# assetID = 'users/samsammurphy/shared/sentinel2/6S/ESRIN_'+dateString

# %%
# # export
# export = ee.batch.Export.image.toAsset(\
#     image=ref,
#     description='sentinel2_atmcorr_export',
#     assetId = assetID,
#     region = region,
#     scale = 30)

# # uncomment to run the export
# export.start()
